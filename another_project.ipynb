# %%
import numpy as np
from typing import Optional,List,Tuple,Dict

class Point:
    
    def __init__(self,x:float,y : float):
        
        self.x = x 
        self.y = y 
        
        
        
## design linecount
class Linecount : 
    
    def __init__(self,start : Point, end : Point , class_name:Optional[List[str]] = None):
        
        self.initial_point = start
        self.end_point = end
        self.count = 0 
        
    
    def check_line_cross(self,dict: Dict) -> Tuple[bool,str]: # return 
        
        
        
        
        pass 
         
    
    def trigger_count(self,dict: Dict) -> None:
        
        # initial point : (x1,x2) 、 end_point(x2,y2)
        # box output  : [(x1,y1),(x1,y2),(x2,y1),(x2,y2)] , i want to extract the center point in box as   
        # box certiod : (box[0]+box[2])/2 , (box[1]+box[2])/2
        
        # trigger_line [(x.,y.),(x.,y.)]
        # i want to design above and below for a image 
        ## first thing  we do slop for caculate y with x 
        # b = y2 - y1 / x2 - x1
        
        for i in list(self.box):
            
            
            # the center of box 
            box_certiod = np.array([(i[0]+i[2]) / 2,(i[1] + i[3])/2])

            # linecount : [[x1,y1],[x2,y2]]
            
            trigger_line = np.array([self.initial_point,self.end_point])
            
            # length of x and  y
              
            y_length  =   trigger_line[1,1] - trigger_line[0,1]
            x_length = (trigger_line[1,0] - trigger_line[0,0])
            
            # slop 
            
            slop = y_length / x_length
            
            if y_length > 0 :
                
                if  > slop*box_certiod[0] 

                     = slop*box_certiod[0]
                
                
            
            else:
                
                
                
                 
                
                
                
                

            if  box_certiod[1] > slop*box_certiod[0] :

                self.count +=  1

            
        
        
     
    
    def reset(self):
        
        self.count = 0
